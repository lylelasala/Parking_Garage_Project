# %% [markdown]
# # Parking Garage Project
#
# Your assignment for today is to create a parking garage class to get more familiar with Object Oriented Programming(OOP).
#
# Your parking gargage class should have the following methods:
# - takeTicket
#    - This should decrease the amount of tickets available by 1
#    - This should decrease the amount of parkingSpaces available by 1
# - payForParking
#    - Display an input that waits for an amount from the user and store it in a variable
#    - If the payment variable is not empty then ->  display a message to the user that their ticket has been paid and they have 15mins to leave
#    - This should update the "currentTicket" dictionary key "paid" to True
# -leaveGarage
#    - If the ticket has been paid, display a message of "Thank You, have a nice day"
#    - If the ticket has not been paid, display an input prompt for payment
#       - Once paid, display message "Thank you, have a nice day!"
#    - Update parkingSpaces list to increase by 1
#    - Update tickets list to increase by 1
#
# You will need a few attributes as well:
# - tickets -> list
# - parkingSpaces -> list
# - currentTicket -> dictionary

# %%
# Your Code will go here
class Parking_Garage():
    
    def __init__(self,parkingSpaces, name):
        self.tickets_available = parkingSpaces
        self.parkingSpaces = parkingSpaces
        self.name = name
        self.id_name = {}


    def takeTicket(self):
        
        ticket_id = input("\nbuy tix?: ")
        self.id_name[ticket_id] = 1           
        self.tickets_available -= 1
        for key, value in self.id_name.items():
            print(f"\nYou purchased {value} ticket and have 15 minutes to leave, i know a rip off hahaha, take your ticket")
 

    def showTicketavailable(self): 
        
            print(f'\n{self.tickets_available} tickets available.') 
      
    def leaveGarage(self):
#         while True:
#             payment = input("Please pay your fee of $15.00 (Type: 15.00): ")
#             if payment != "15.00":
#                 print("Incorrect amount.")
#                 self.checkoutTicket()
#             else:
#               print(f" \nThanks for parking at {self.name}.\nHave a nice day!")
#             break

        ticket = ParkingTicket
        if ticket:
            print("Thank You, have a nice day!")
        else:
        # Prompt for payment
            payment = input("Please pay for your parking ticket: ")
        # Update ticket status to paid
            ticket.paid = True
            print("Thank you, have a nice day!")

    # Update parkingSpaces list
            self.parkingSpaces += 1

    # Update tickets list
            self.tickets += 1

    def run(self):
           
    
        while True:
            quest_name = input("Whats your name: ")
            
            response = input(f"\nWelcome to the garage! it is $1.00 a minute to park! \nWhat are you doing {quest_name.title()}? Entering/Exiting/Show (tickets)/quit: ").lower()

            if response == 'entering':
                self.takeTicket()

            elif response == 'exiting':
                self.leaveGarage()
                
                
            elif response == 'show':
                self.showTicketavailable()
            elif response == 'quit':
                print("\nHave a nice day! ")
                break
            else:
                print("Invalid entry. Please try again, doofus.")



lyles_Garage = Parking_Garage(100, "garage")
            
lyles_Garage.run()
# Out:
# Whats your name: David
#
# Welcome to the garage! it is $1.00 a minute to park!
# What are you doing David? Entering/Exiting/Show (tickets)/quit: Entering
#
# buy tix?: yehahaha
#
# You purchased 1 ticket and have 15 minutes to leave, i know a rip off hahaha, take your ticket
# Whats your name: David
#
# Welcome to the garage! it is $1.00 a minute to park!
# What are you doing David? Entering/Exiting/Show (tickets)/quit: Exiting
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14096\654950740.py in <module>
#      75 lyles_Garage = Parking_Garage(100, "garage")
#      76
# ---> 77 lyles_Garage.run()
#
# ~\AppData\Local\Temp\ipykernel_14096\654950740.py in run(self)
#      60
#      61             elif response == 'exiting':
# ---> 62                 self.leaveGarage()
#      63
#      64
#
# ~\AppData\Local\Temp\ipykernel_14096\654950740.py in leaveGarage(self)
#      32 #             break
#      33
# ---> 34         ticket = ParkingTicket
#      35         if ticket:
#      36             print("Thank You, have a nice day!")
#
# NameError: name 'ParkingTicket' is not defined
